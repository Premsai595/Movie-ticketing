# %%
import Movie
Book_movie = Movie.Movie_Booking()
while True:
    print("SELECT WHAT DO YOU WANT IN NUMBERS ONLY".center(100, "*"))
    print("1. Show_seating")
    print("2. Buy_ticket")
    print("3. Statistics")
    print("4. Show the details of the user")
    print("0. Exit")

    choice = input("please select your choice from above!!")
    while choice.isdigit() == False:
        print("please select your choice from above: ")
        choice = input("please select your choice from above!!")
        continue

    choice = int(choice)

    if choice == 0:
        print(" THANKYOU , VISIT AGAIN".center(100, "*"))
        break
    if choice == 1:
        Book_movie.Show_seating()
    elif choice == 2:
        Book_movie.Buy_ticket()
    elif choice == 3:
        Book_movie.Stats()
    elif choice == 4:
        Book_movie.get_details()
# Out:
# ***Welcome To RRR Movie**
# Please seating capacity Of the Movie
# Enter Number of rows you need:  5
# Enter number of columns you need:  5
# ******************************SELECT WHAT DO YOU WANT IN NUMBERS ONLY*******************************
# 1. Show_seating
# 2. Buy_ticket
# 3. Statistics
# 4. Show the details of the user
# 0. Exit
# please select your choice from above!!1
# ************************************** screen is on this side **************************************
# SEATS:
# S S S S S
# S S S S S
# S S S S S
# S S S S S
# S S S S S
# ******************************SELECT WHAT DO YOU WANT IN NUMBERS ONLY*******************************
# 1. Show_seating
# 2. Buy_ticket
# 3. Statistics
# 4. Show the details of the user
# 0. Exit
# please select your choice from above!!1
# ************************************** screen is on this side **************************************
# SEATS:
# S S S S S
# S S S S S
# S S S S S
# S S S S S
# S S S S S
# ******************************SELECT WHAT DO YOU WANT IN NUMBERS ONLY*******************************
# 1. Show_seating
# 2. Buy_ticket
# 3. Statistics
# 4. Show the details of the user
# 0. Exit
# please select your choice from above!!2
# Please select the Seat,  of enter the rows and columns of movie size
# **** BOOKING COUNTER ****
# Please choose/Select seats between 5 Rows and 5 Columns  !! only !!
# select the row: 2
# select the column: 2
# Please select the name in alphabets!
# Please enter your name: p
# Please enter your age: 3
# Please select your gender Female/Male/Other: male
# Please enter your phone number99
# Confirm to book seats(Yes/No): yes
# Your ticket price is 10$, if you want to confirm type Yes/No: yes
# ***SCREEN IS THIS SIDE***
# S S S S S
# S B S S S
# S S S S S
# S S S S S
# S S S S S
# ******************************SELECT WHAT DO YOU WANT IN NUMBERS ONLY*******************************
# 1. Show_seating
# 2. Buy_ticket
# 3. Statistics
# 4. Show the details of the user
# 0. Exit
# please select your choice from above!!3
# It shows Income of the Booked tickets of Movie!!!!
# Total number of seats booked are :  1
# Booking percentage is :  4.0
# current income is : 10 $
# Total income is: 250 $
# ******************************SELECT WHAT DO YOU WANT IN NUMBERS ONLY*******************************
# 1. Show_seating
# 2. Buy_ticket
# 3. Statistics
# 4. Show the details of the user
# 0. Exit
# please select your choice from above!!4
# ***DETAILS OF CUSTOMER***
# Please enter row number you want: 2
# Please enter column number you want: 2
# name: P
# age: 3
# Gender: Male
# Phone Number: 99
# Ticket Price: 10$
# ******************************SELECT WHAT DO YOU WANT IN NUMBERS ONLY*******************************
# 1. Show_seating
# 2. Buy_ticket
# 3. Statistics
# 4. Show the details of the user
# 0. Exit
# please select your choice from above!!4
# ***DETAILS OF CUSTOMER***
# Please enter row number you want: 0
# Please enter column number you want: 0
# We dont have that seat
# ******************************SELECT WHAT DO YOU WANT IN NUMBERS ONLY*******************************
# 1. Show_seating
# 2. Buy_ticket
# 3. Statistics
# 4. Show the details of the user
# 0. Exit
